# %% [markdown]
# ETL of the rainfall patterns till date

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ci is the data frame that contains Central India Rainfall Arrival and Departure<br>
# ne contains North India's Rainfall Act-Dep info<br>
# pan_i contains India's Rainfall Act-Dep info

# %%
ci=(pd.read_csv("central-India_rainfall_act_dep_1901_2016.csv"))

# %%
ci.head(5)
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                  99.3                 295.4                 354.8
# 1  1902                  62.3                 334.2                 237.6
# 2  1903                  96.2                 392.7                 286.6
# 3  1904                 180.5                 259.1                 200.9
# 4  1905                  59.8                 340.6                 178.9
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 0                  113.8                      863.3
# 1                  216.0                      850.0
# 2                  211.5                      987.1
# 3                  165.8                      806.3
# 4                  204.1                      783.4
#
#    Departure Percentage: JUN  Departure Percentage: JUL  \
# 0                      -39.6                      -16.0
# 1                      -62.4                       -4.8
# ...

# %%
ci.plot()

# %%
plt.show(ci.bool())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-c1ca269dd15a> in <module>
# ----> 1 plt.show(ci.bool())
#
# ~/anaconda3/envs/green_leaf/lib/python3.6/site-packages/pandas/core/generic.py in bool(self)
#    1592                              "{0}".format(self.__class__.__name__))
#    1593
# -> 1594         self.__nonzero__()
#    1595
#    1596     def __abs__(self):
#
# ~/anaconda3/envs/green_leaf/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
ci.dtypes
# Out:
# YEAR                                int64
# Actual Rainfall: JUN              float64
# Actual Rainfall: JUL              float64
# Actual Rainfall: AUG              float64
# Actual Rainfall: SEPT             float64
# Actual Rainfall: JUN-SEPT         float64
# Departure Percentage: JUN         float64
# Departure Percentage: JUL         float64
# Departure Percentage: AUG         float64
# Departure Percentage: SEP         float64
# Departure Percentage: JUN-SEPT    float64
# dtype: object
